# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_1 = pd.read_csv(r"C:\Users\HP\Downloads\dataset_1 - dataset_1.csv")
data_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
data_1.dropna(inplace=True)
data_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %% [markdown]
# ##Drop columns

# %%
newdata_1 = data_1.drop(['yr','mnth'],axis=1)
newdata_1
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 605      606  28-01-2011       1  11    False        5           3  0.18
# 606      607  28-01-2011       1  12    False        5           3  0.18
# 607      608  28-01-2011       1  13    False        5           3  0.18
# 608      609  28-01-2011       1  14    False        5           3  0.22
# 609      610  28-01-2011       1  15    False        5           2  0.20
#
# [610 rows x 8 columns]

# %%
sns.violinplot(data= newdata_1,x='weathersit',y='temp')
# Out:
# <Axes: xlabel='weathersit', ylabel='temp'>

# %%
newdata_1.plot(kind='bar', x='weathersit',y='temp')
# Out:
# <Axes: xlabel='weathersit'>

# %%
sns.displot(newdata_1['weathersit'])

# %%
data_2 = pd.read_csv(r"C:\Users\HP\Downloads\dataset_2.xlsx - dataset_2.csv")
data_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
data_2.dropna(inplace=True)
data_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [599 rows x 8 columns]

# %%
newdata_2 = data_2.drop('Unnamed: 0',axis=1)
newdata_2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [599 rows x 7 columns]

# %%
sns.violinplot(data= newdata_2,x='windspeed',y='registered')
# Out:
# <Axes: xlabel='windspeed', ylabel='registered'>

# %%
newdata_2.plot(kind='bar', x='windspeed',y='registered')
# Out:
# <Axes: xlabel='windspeed'>

# %%
sns.displot(newdata_2['windspeed'])

# %%
merged_data = pd.merge(newdata_1,newdata_2,on='instant',how='right')
print(merged_data.to_string())
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0          1  01-01-2011       1   0    False        6           1  0.24  0.2879  0.81     0.0000       3          13   16
# 1          2  01-01-2011       1   1    False        6           1  0.22  0.2727  0.80     0.0000       8          32   40
# 2          3  01-01-2011       1   2    False        6           1  0.22  0.2727  0.80     0.0000       5          27   32
# 3          4  01-01-2011       1   3    False        6           1  0.24  0.2879  0.75     0.0000       3          10   13
# 4          5  01-01-2011       1   4    False        6           1  0.24  0.2879  0.75     0.0000       0           1    1
# 5          6  01-01-2011       1   5    False        6           2  0.24  0.2576  0.75     0.0896       0           1    1
# 6          7  01-01-2011       1   6    False        6           1  0.22  0.2727  0.80     0.0000       2           0    2
# ...

# %%
merged_data
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 594      606  28-01-2011       1  11    False        5           3  0.18
# 595      607  28-01-2011       1  12    False        5           3  0.18
# 596      608  28-01-2011       1  13    False        5           3  0.18
# 597      609  28-01-2011       1  14    False        5           3  0.22
# 598      610  28-01-2011       1  15    False        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     599 non-null    int64
#  1   dteday      599 non-null    object
#  2   season      599 non-null    int64
#  3   hr          599 non-null    int64
#  4   holiday     599 non-null    bool
#  5   weekday     599 non-null    int64
#  6   weathersit  599 non-null    int64
#  7   temp        599 non-null    float64
#  8   atemp       599 non-null    float64
#  9   hum         599 non-null    float64
#  10  windspeed   599 non-null    float64
#  11  casual      599 non-null    int64
#  12  registered  599 non-null    int64
#  13  cnt         599 non-null    int64
# dtypes: bool(1), float64(4), int64(8), object(1)
# memory usage: 61.5+ KB

# %%
merged_data.dropna(inplace=True)
merged_data
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 594      606  28-01-2011       1  11    False        5           3  0.18
# 595      607  28-01-2011       1  12    False        5           3  0.18
# 596      608  28-01-2011       1  13    False        5           3  0.18
# 597      609  28-01-2011       1  14    False        5           3  0.22
# 598      610  28-01-2011       1  15    False        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
sns.violinplot(data= merged_data,x='dteday',y='cnt')
# Out:
# <Axes: xlabel='dteday', ylabel='cnt'>

# %%
merged_data.plot(kind='bar',x='dteday',y='cnt')
# Out:
# <Axes: xlabel='dteday'>

# %%
sns.displot(merged_data['dteday'])

# %%
data_3 = pd.read_csv(r"C:\Users\HP\Downloads\dataset_3 - dataset_3.csv")
data_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
data_3.dropna(inplace=True)
data_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
newdata_3 = data_3.drop(['yr','mnth'],axis=1)
newdata_3
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0        620  29-01-2011       1   1    False        6           1  0.22
# 1        621  29-01-2011       1   2    False        6           1  0.22
# 2        622  29-01-2011       1   3    False        6           1  0.20
# 3        623  29-01-2011       1   4    False        6           1  0.16
# 4        624  29-01-2011       1   6    False        6           1  0.16
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 385      615  28-01-2011       1  20    False        5           2  0.24
# 386      616  28-01-2011       1  21    False        5           2  0.22
# 387      617  28-01-2011       1  22    False        5           1  0.24
# 388      618  28-01-2011       1  23    False        5           1  0.24
# 389      619  29-01-2011       1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
sns.violinplot(data= newdata_3,x='season',y='hum')
# Out:
# <Axes: xlabel='season', ylabel='hum'>

# %%
newdata_3.plot(kind='bar',x='season',y='hum')
# Out:
# <Axes: xlabel='season'>

# %%
sns.displot(newdata_3['season'])

# %%
new_dataset = pd.concat([merged_data,newdata_3],ignore_index=True)
new_dataset
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 984      615  28-01-2011       1  20    False        5           2  0.24
# 985      616  28-01-2011       1  21    False        5           2  0.22
# 986      617  28-01-2011       1  22    False        5           1  0.24
# 987      618  28-01-2011       1  23    False        5           1  0.24
# 988      619  29-01-2011       1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     989 non-null    int64
#  1   dteday      989 non-null    object
#  2   season      989 non-null    int64
#  3   hr          989 non-null    int64
#  4   holiday     989 non-null    bool
#  5   weekday     989 non-null    int64
#  6   weathersit  989 non-null    int64
#  7   temp        989 non-null    float64
#  8   atemp       989 non-null    float64
#  9   hum         989 non-null    float64
#  10  windspeed   989 non-null    float64
#  11  casual      989 non-null    int64
#  12  registered  989 non-null    int64
#  13  cnt         989 non-null    int64
# dtypes: bool(1), float64(4), int64(8), object(1)
# memory usage: 101.5+ KB

# %%
new_dataset.dropna(inplace=True)
new_dataset
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 984      615  28-01-2011       1  20    False        5           2  0.24
# 985      616  28-01-2011       1  21    False        5           2  0.22
# 986      617  28-01-2011       1  22    False        5           1  0.24
# 987      618  28-01-2011       1  23    False        5           1  0.24
# 988      619  29-01-2011       1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
new_dataset.dropna(inplace=True)
new_dataset
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 984      615  28-01-2011       1  20    False        5           2  0.24
# 985      616  28-01-2011       1  21    False        5           2  0.22
# 986      617  28-01-2011       1  22    False        5           1  0.24
# 987      618  28-01-2011       1  23    False        5           1  0.24
# 988      619  29-01-2011       1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
sns.violinplot(data= new_dataset,x='weekday',y='cnt')
# Out:
# <Axes: xlabel='weekday', ylabel='cnt'>

# %%
new_dataset.plot(kind='bar',x='weekday',y='cnt')
# Out:
# <Axes: xlabel='weekday'>

# %%
sns.displot(new_dataset['casual'])

# %% [markdown]
# ##OUTLIERS

# %%
new_dataset.boxplot(column='atemp')
# Out:
# <Axes: >

# %%
from scipy.stats import skew

# %%
skewness = new_dataset['temp'].skew()

print("Skewness of dates:", skewness)
# Out:
# Skewness of dates: 0.5064712631265815

# %%
from scipy.stats import kurtosis

# %%
kurtosis = new_dataset['temp'].kurt()

print("kurtosis of dates:", kurtosis)
# Out:
# kurtosis of dates: 0.7273262236053153
